# %% [markdown]
# <a href="https://colab.research.google.com/github/ShalomGustav/150723/blob/master/Fatikhov_MS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd

# %% [markdown]
# Без get_dummies, не знаю как сделать.

# %%
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  robot
# 4  human

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0       1      0
# 1       1      0
# 2       0      1
# 3       0      1
# 4       1      0
# 5       1      0
# 6       0      1
# 7       1      0
# 8       0      1
# 9       0      1
# 10      0      1
# 11      0      1
# 12      1      0
# 13      0      1
# 14      0      1
# 15      1      0
# 16      1      0
# 17      1      0
# 18      1      0
# 19      0      1
